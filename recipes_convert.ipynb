# %% [markdown]
# ### Recipes Convert
#
# This notebook explores converting a preprocessed recipe file into the satisfactory tools format.
#
# ---
#
# Overview of that format:
#
# 1. Recipes - the thing we're going for the most.
#     * slug + name
#     * className - a unique recipe ID that seems to be used like a slug. Not sure why it's not just the slug.
#     * alternate - we'll need to come up with this, whether this is the primary way for getting a resource or not. Informs which recipes are used by default
#     * time - time to craft (very relevant)
#     * manualTimeMultiplier - used in Satisfactory, doesn't matter for greg but we'll need to include a placeholder.
#     * ingredients - a list of ingredients, each with a className (NOT slug) and amount
#     * forBuilding - I don't think this is actually used in SatisfactoryTools? The buildings tab is built from the buildings list at the root level.
#     * inMachine + inHand + inWorkshop - can this recipe be done by x? Affect what info is shown in the UI. We'll need to come up with this
#     * products - a list of products, each with a className (NOT slug) and amount
#     * isVariablePower - used in Satisfactory, I don't think it matters for greg but we'll need to include a placeholder. If true,  we'll need to specify minPower and maxPower, the UI will show the "Average" as the average of those two.
#     * producedIn - if it can be made inMachine, what machine(s)? uses className. Machines inform power use calculations so we'll need to be smart about this one.
# 2. Items
#     * slug + name + className
#     * stackSize - how many can be in a stack
#     * liquid
#     * radioactivity - not sure if we dump/have access to this information for greg items
#     * sinkPoints - coming up with a value for this would help inform default recipes, actually.
#     * fluidColor - we throw this data away rn, actually. We could use it to inform the UI.
#     * fuelValue - relevant to greg but I explicitly ignore fuel values rn
# 3. Schematics - research exists in Satisfactory. We'll leave this blank.
# 4. Generators - technically relevant to greg. The UI has references to this data but I think the UI components for that code aren't turned on/included in the website. Leave blank and hopefully nothing breaks.
# 5. Resources - seems to define what can be mined. This will be a tough one to fill in as we'll have to determine what users will want to have an inputs in the normal case. There will also be *so many of them* that the UI will prolly struggle.
#     * item className - corresponds to listing in Items
#     * pingColor - relevant to the game but not SatistactoryTools and not greg
#     * speed - mining speed I think? It's 1 for every Satisfactory resource.
# 6. Miners - only seems to be used in the UI to determine whether something is a manufacturer? Try leaving it blank.
# 7. Buildings - important field, lists machines and power consumption.
#     * slug + name + className
#     * metadata - stuff about power. powerConsumption is quite relevant, but powerConsumptionExponent seems to be overriden in the UI to 1.6, so it doesn't matter. The code suggests that there should be a way to manually set the overclock, but I can't seem to find it. We'll assume no overclocking for this first version. I'll need to edit the UI to not calculate overclocks too, becuase the rules are different for greg vs. Satisfactory.
#     * size - doesn't seem to be used in the UI, set to 0.
#     * buildMenuPriority - doesn't seem to be used in the UI, set to 0.
#     * category - not used in the UI, leave blank.

# %% [markdown]
# # Stuff to figure out
# ---
#
# - [ ] classNames for everything. The Desc_ / Build_ / BP_ / ResourceSink_ / etc. prefixes appear in the codebase but so far as I can tell are only used to gather information for the codex. I think using Desc_ for all items and Build_ for all buildings will satiate the UI, but I'm not sure. It might reduce file size to omit them.
# - [ ] Nice user-facing names for everything. This is a big one, especially for recipes, as users will need to be able to quicky filter through a lot of them.
# - [ ] A smart filter for what we include in the output file! We don't want to include every single item in the game, just the ones that are relevant to the user. The UI is going to be hella loaded down as it is.
# - [ ] Machines + their power consumption. The same class of machine in greg can have many different tier-based power consumptions. As a hack, we'll add a different machine for every tier. This will take some work.
# - [ ] Determine what is an input resource. Probably will be based on an oredict rule.
# - [ ] How to determine the primary and alternate recipes for a resource. This is a big one - maybe the biggest - because starting with reasonable defaults for each item will make life much easier for the user, but it will require not-obvious logic to determine what is more expensive/higher tier to make.
# - [ ] Sink Value - the Satisfactory meaning doesn't exist in greg, but it might still be useful to calculate as an intermediary to selecting primary recipes.
# - [ ] There are a bunch of constants in the UI that seem to inform the UI, like names for water, radioactive waste, etc. We can try omitting them to start.
# - [ ] Descriptions for items in the UI. Certainly not necessary to start, but including some metadata we've got lying about, like source mod
# - [ ] Other things...?

# %%
from tools.nerd_format import RecipeFile
from tools.dump_format import RecipeStacks
from tools.util import parse_json, load_config

config = load_config()
recipes = parse_json("data/recipes_filtered.json", RecipeFile)
stacks = parse_json("data/recipes_stacks.json", RecipeStacks)

# %%
# Lets start filling out formatted data! Start with items
from tools.dump_format import GTFluid
from tools.st_format import Item
import numpy as np

def get_name(slug):
    if slug in stacks.items:
        return stacks.items[slug].displayName
    if slug in stacks.fluids:
        fluid = stacks.fluids[slug]
        return fluid.localizedName if isinstance(fluid, GTFluid) else fluid.fluidName
    return "Unknown"

# There are some items we never reference in a recipe. To reduce output sizes somewhat, we'll filter them out.
recipe_slugs = set()
for recipe in recipes.recipes:
    recipe_slugs.update(i.slug for i in recipe.inputs + recipe.outputs)
print("total:", len(stacks.items)+len(stacks.fluids), "used in recipes:", len(recipe_slugs))
known_slugs = set(stacks.items.keys()) | set(stacks.fluids.keys())
missing = recipe_slugs - known_slugs
print("Items missing from stacks:", len(missing), "Examples:", np.random.choice(list(missing), 5))
used_items = known_slugs & recipe_slugs
print("Items used in recipes:", len(used_items))
# Out:
# total: 30577 used in recipes: 25082
# Items missing from stacks: 922 Examples: ['4350d12990' '4350d3926' '4350d4512' '4350d3368' '4350d3905']
# Items used in recipes: 24160

# %%
[get_name(item) for item in used_items]
# Out:
# ['Impure Pile of Sapphire Dust',
#  'Nitinol 60 Rotor',
#  'Bismuth Turbine Blade',
#  'Tantalum Carbide Bolt',
#  'Green Sapphire Ore',
#  'Smooth Black Granite',
#  'Crushed Vulcanite Ore',
#  '16x Cobalt Wire',
#  'Block of Bismuth',
#  'Tiny Pile of Americium Dust',
#  'Coil Wire [LuV]',
#  'Tanzanite Ore',
#  'Double Molybdenum Ingot',
#  'SpaceTime Frame Box',
#  'Pig Iron Shovel Head',
#  'Raw Tengam Ore',
#  'Adamantium Ore',
#  'Chrome Ore',
#  'Small Tellurium Spring',
#  'Pikyonium 64B Ingot',
#  'Orichalcum Arrow Head',
#  'Purified Pile of Platinum Dust',
#  'Crushed Huebnerite Ore',
#  'Quintuple Ichorium Plate',
#  'Livingwood Foil',
#  'Arceus Alloy 2B Rod',
#  'Transmission Component (ZPM)',
#  '30k Coolant Cell',
#  'Banded Iron Ore',
#  'Long Superconductor Base HV Rod',
#  'Ruthenium Ingot',
#  'Terraformer',
#  'Molten Magnetic Samarium Capsule',
#  'ME Dense Smart Cable - Magenta',
#  'Methanol Cell',
#  'Purified Irarsite Dust',
#  'Extruder Shape (Gear)',
#  'Small Pile of Sodium Methoxide Dust',
#  'Quadruple Carbon Plate',
#  'Advanced Recycler',
#  'Magnetic Neodymium Rotor',
#  'Long HS188-A Rod',
#  'Cosmic Neutronium Axe Head',
#  'Aluminum Ingot',
#  'Large Neutronium Fluid Cell',
#  'Wrap of SMD Transistors',
#  'Pulsating Iron Screw',
#  'Impure Pile of Calcium Hydride Dust',
#  'Magnalium Arrow Head',
#  'Double Tungsten Ingot',
#  'Sliced Bun',
#  'hypochlorousacid',
#  'Potion of Strength',
#  'Ebony Plank',
#  'Rose Gold Plow Head',
#  'Sapphire Arrow',
#  'Moderately Steam-Cracked Ethane Cell',
#  'Bolted Naquadah Alloy Casing',
#  'Small Alduorite Spring',
#  'Centrifuged Lepidolite Ore',
#  'Double Polyvinyl Chloride Bar',
#  'Shadow Metal Hammer Head',
#  'Turbine Shaft',
#  'Palladium Plate',
#  'Nickel Plate',
#  'Magnalium Nugget',
#  'Adamantium Ore',
#  'Infinity Catalyst Plate',
#  'Oak Wood Planks',
#  'Elite Magneto Resonatic Circuit',
#  'Long Salt Rod',
#  'Flawless Dragonstone',
#  'Small Palladium Gear',
#  'Purified Pile of Sheldonite Dust',
#  'Centrifuged Sodalite Ore',
#  'Windmill',
#  'EV 64A/t Low Power Laser Converter',
#  'Double Polyvinyl Chloride Sheet',
#  'Aluminium Rotor',
#  'Amber Plate',
#  'Molten SpaceTime Capsule',
#  'Epoxid Screw',
#  'Uranium 233 Dust',
#  'Golden Electron Tube',
#  'Block of Ordo',
#  'Impure Pile of Amethyst Dust',
#  'Molten Beryllium Cell',
#  'Sodium Nitrate Dust',
#  'Light Aer Arrow',
#  'Purified Perlite Ore',
#  'Small Pile of Rose Gold Dust',
#  'Medium Voltage Energy Buffer',
#  'Crushed Stibnite Ore',
#  'Purified Nether Star Ore',
#  'Conductiveiron Comb',
#  'Triple Ceruclase Plate',
#  'Polycaprolactam Rod',
#  'Advanced Electric Oven',
#  'Yellow Garnet Ore',
#  'Dense Elven Elementium Plate',
#  'Quintuple Polystyrene Bar',
#  'Adamantium Shovel Head',
#  'Advanced Blocking Card',
#  'Inconel-792 Gear',
#  'Octiron Gear',
#  'Purified Crushed Yttrialite Ore',
#  'Oak Wood Planks',
#  'Sealed Wood Plank',
#  'Superconductor Base UEV Ingot',
#  'Small Stellar Alloy Gear',
#  'Programmed Circuit',
#  'molten.naquadahenriched',
#  'Fish Jerky',
#  'Centrifuged Sulfur Ore',
#  'Auto Workbench (HV)',
#  'Neodymium Frame Box',
#  'Ice Tea',
#  'Small Pile of Roasted Zinc Dust',
#  'Incoloy-DS Rotor',
#  'Wrought Iron Rotor',
#  'Palladium Ore',
#  'Double Endium Plate',
#  'potion.scotch',
#  'Crushed Ceruclase Ore',
#  'HV Machine Casing',
#  'Tiny Pile of Trona Dust',
#  'Ichorium Universal Spade Head',
#  'Small Mysterious Crystal Spring',
#  'Tin Ingot',
#  'Oxygen Collector',
#  '2x Steel Cable',
#  'Grossular Ore',
#  'Fine Lanthanum Wire',
#  'Stone',
#  'Gaia Spirit Dust',
#  'Black Steel Nugget',
#  'Molten Ultimet Capsule',
#  'Electrical Steel Universal Spade Head',
#  'Amethyst Ore',
#  'Purified Cadmium Ore',
#  '1x Tungstensteel Cable',
#  'Advanced Boiler [LV]',
#  'Double Alumite Plate',
#  'Hypogen Foil',
#  'Plutonium 239 Plate',
#  'Block of Tungstensteel',
#  'plasma.uranium235',
#  'Acid Generator MV',
#  'Quadruple Elven Elementium Plate',
#  'Centrifuged Glauconite Sand',
#  'Wenge Stairs',
#  'Cupronickel Sword Blade',
#  'Redstone Torch',
#  'Centrifuged Red Zircon Ore',
#  'End Steel Frame Box',
#  'Quadruple Vanadium-Gallium Ingot',
#  'Californium Ingot',
#  'Superconductor Base UHV Round',
#  'Black Plutonium Plate',
#  'Triple Scandium Ingot',
#  'Purified Cosmic Neutronium Ore',
#  'Yttrium Spring',
#  'Duranium Arrow Head',
#  'Black Bronze Chainsaw Tip',
#  'Small Pile of Quantum Dust',
#  'Small Pile of Fireclay Dust',
#  'Tiny Pile of Thorium 232 Dust',
#  'Dense Molybdenum Plate',
#  'Tritanium Pickaxe Head',
#  'Lead Pickaxe Head',
#  'Dense Incoloy-020 Plate',
#  'Small Pile of Organorhodium Catalyst Dust',
#  'molten.europium',
#  'Blank Pattern',
#  'Pyrolusium Leaf',
#  'Small Plutonium 239 Spring',
#  'Sterling Silver Casing',
#  'Programmed Circuit',
#  'Triple Stellar Alloy Ingot',
#  'Hastelloy-X Rotor',
#  'Hastelloy-X Bolt',
#  'ZPM 128A/t Low Power Laser Converter',
#  'Flawless Tanzanite',
#  'Clay Compound Dust',
#  'Quintuple Ironwood Plate',
#  'Deep Iron Ore',
#  'Steam Extractor',
#  'Gallium Arsenide Ring',
#  'Impure Pile of Flerovium Dust',
#  'Advanced Wiremill',
#  'Molten Obsidian Bucket',
#  'Small Pile of Attuned Tengam Dust',
#  'Void Spring',
#  'Bright Illuminated Panel',
#  'Brown Limonite Dust',
#  'Damaged Rubber Dinghy',
#  'Zinc Bolt',
#  'Small Pile of Thorianite Dust',
#  'Nichromite Ore',
#  'Oak Wood Planks',
#  'Antimony Ore',
#  'Lithium 7 Dust',
#  'Tiny Pile of Emerald Dust',
#  'Naquadria Round',
#  'Superconductor Base ZPM Ingot',
#  'Soldering Alloy Bolt',
#  'Nonuple Steel Fluid Pipe',
#  'Double Gadolinium Ingot',
#  'Tungsten Arrow',
#  'Double Uranium 235 Ingot',
#  'White Metal Foil',
#  'Refinery',
#  'Polycaprolactam Rotor',
#  'Advanced Bending Machine',
#  'lightlysteamcracked.lightfuel',
#  'Tiny Pile of Triphenylphosphine Dust',
#  'Muffler Hatch (UV)',
#  'Small Pile of Vinteum Dust',
#  'Superconductor Base UEV Casing',
#  'Naquadah Alloy Ring',
#  'Almandine Ore',
#  'Containment Unit II',
#  'Clay Compound Hoe Head',
#  'Quadruple Cupronickel Ingot',
#  'Aqua Infused Stone',
#  'Hastelloy-N Bolt',
#  'Steel Universal Spade Head',
#  'Infinity Catalyst Spring',
#  'Shadow Iron Ore',
#  'Thorium File Head',
#  'Infinity Catalyst Buzzsaw Blade',
#  'Bolted Bismuth Bronze Casing',
#  'Kaolinite',
#  'Brass Bolt',
#  'Iron Hoe',
#  'Certus Quartz Ore',
#  'Block of Radium',
#  'Olenite Rod',
#  'Infinity Booster Card',
#  'Double Infused Gold Plate',
#  'Leach Residue Ore',
#  'Triple Shadow Steel Ingot',
#  'Maple Wood Slab (Fireproof)',
#  'Oriharukon Wrench Tip',
#  'Electrum Sense Blade',
#  'Block of Thorium',
#  'molten.yttriumbariumcuprate',
#  'Purified Tengam Buzzsaw Blade',
#  'Ammonium Bifluoride Cell',
#  'Stone Slab',
#  'Asteroid Rock',
#  'Realgar Gear',
#  'Crushed Cerite Ore',
#  'Flawed Yellow Garnet',
#  'Quadruple Tellurium Plate',
#  'Dense Vyroxeres Plate',
#  'Double Knightmetal Ingot',
#  'Fine Cobalt Wire',
#  'Quintuple Nickel Aluminide Plate',
#  'Advanced Electromagnetic Separator IV',
#  'Magnetic Samarium Sword Blade',
#  'Thaumium Sword Blade',
#  'Proton Cell',
#  'Black Plutonium Casing',
#  'Perditio Axe Head',
#  'Rhodium Sulfate Capsule',
#  'Lightly Hydro-Cracked Light Fuel Cell',
#  'Uranium 238 Plate',
#  'Ichorium Rod',
#  'Lead Lined Box',
#  'Poppy',
#  'Block of Arsenic',
#  'Molten Attuned Tengam Capsule',
#  'Ancient Granite Plate',
#  'Epoxy Circuit Board',
#  'Triple Lithium Ingot',
#  'Vanadiumsteel Round',
#  'Neodymium Drill Tip',
#  'Reinforced Casing',
#  'Molten Dark Steel Capsule',
#  'Beryllium Hoe Head',
#  'Steeleaf Foil',
#  'Vyroxeres Hoe Head',
#  'Lemon Slice',
#  'Quintuple Adamantium Plate',
#  'Purified Pyrite Ore',
#  'HSS-E Ingot',
#  'Mica Ore',
#  'Superconductor Base EV Plate',
#  'Programmed Bio Circuit',
#  'Dense Maraging Steel 300 Plate',
#  'Quintuple Brass Plate',
#  'Thallium Rod',
#  'Vulcanite Screw',
#  'Vanadiumsteel Dust',
#  'Tiny Pile of Callisto Ice Dust',
#  'Triple Osmiridium Plate',
#  'Small Enriched Holmium Spring',
#  'Triple Ademic Steel Plate',
#  'Advanced Cutting Machine',
#  'Tiny Pile of Rhodium Chloride Dust',
#  'Long Tritanium Rod',
#  'potion.slowness.long',
#  'Electrotine Plate',
#  'Small Pile of Callisto Ice Dust',
#  'Block of HSS-S',
#  'Magnetic Neodymium Plate',
#  'Forcillium Ore',
#  'Small Infinity Gear',
#  'Opal Lens',
#  'Tungsten Axe Head',
#  'Tritanium Plate',
#  'HSS-E Shovel Head',
#  'Small Chrysotile Gear',
#  'Quintuple Uranium 235 Plate',
#  'Livingwood Rod',
#  'Terrasteel Casing',
#  'Small Infinity Catalyst Spring',
#  'Vermiculite',
#  'Oganesson Capsule',
#  'Triple Lead Ingot',
#  'Brass Pickaxe Head',
#  'Tiny Pile of Stone Dust',
#  'Enriched Naquadah Ore',
#  'Olenite Plate',
#  'Thunder Leaf',
#  'ME Dense Smart Cable - Fluix',
#  'Small Pile of Ledox Dust',
#  'Naquadah Alloy Bolt',
#  'Hot Incoloy-MA956 Ingot',
#  'Quintuple Mithril Plate',
#  'Dense Gaia Spirit Plate',
#  'Diluted Sulfuric Acid Cell',
#  'Tin Alloy Buzzsaw Blade',
#  'Ademic Steel Screw',
#  'Miessiite Ore',
#  'Lapis Brick',
#  'Tiny Pile of Superconductor Base MV Dust',
#  'Cobalt II Acetate Dust',
#  'Block of Titanium',
#  'Gaia Spirit Foil',
#  'Kyanite Ore',
#  'Asbestos Dust',
#  'Marble Hoe Head',
#  'Quadruple End Steel Plate',
#  'Centrifuged Gypsum Ore',
#  'Polystyrene Sense Blade',
#  'Quintuple Purified Tengam Ingot',
#  'Iron Turning Blank',
#  'Triple Superconductor Base EV Ingot',
#  'Small Neodymium Spring',
#  'Quintuple Tungstencarbide Ingot',
#  'Bog Earth',
#  'Block of Inconel-792',
#  'Alumite Hammer Head',
#  'Long Magnalium Rod',
#  'Black Granite',
#  'Double Infinity Catalyst Ingot',
#  'Uranium 233 Rod',
#  'Small Fiber-Reinforced Epoxy Resin Spring',
#  'Draconium Ore',
#  'Beealyzer',
#  'Small Pile of Diamond Dust',
#  'Annealed Copper Bolt',
#  'Blue Alloy Bolt',
#  'Electrical Steel Pickaxe Head',
#  'Livingwood Sword Blade',
#  'Tin Screw',
#  'Double Ytterbium Plate',
#  'Quintuple HSS-E Plate',
#  'Purified Pile of Amber Dust',
#  'Thulium Ore',
#  'Quadruple Red Steel Plate',
#  'Crystalline Alloy Rotor',
#  'Firebricks',
#  'Stone Slab',
#  'Fine Meteoric Iron Wire',
#  'Flawed Topaz',
#  'Willow Plank',
#  'Silicon Carbide Ingot',
#  'Hot Ruthenium Ingot',
#  'Steel Plow Head',
#  'Quadruple Naquadah Alloy Ingot',
#  'Spinel Bolt',
#  'Osmium Solution Capsule',
#  'Plutonium 239 Arrow Head',
#  'Laurenium Gear',
#  'Tiny Pile of Sterling Silver Dust',
#  'Small Melodic Alloy Gear',
#  'Black Plutonium Arrow Head',
#  'Fine Eternity Wire',
#  'Tiny Pile of Plutonium',
#  'Yellow Stained Glass',
#  'Uranium 235 Turbine Blade',
#  'Steeleaf Universal Spade Head',
#  'Double Thaumium Ingot',
#  'Vanadium-Gallium Screw',
#  'Tiny Pile of Lapis Dust',
#  'Botmium Ring',
#  'Tritanium Turbine Blade',
#  'Tiny Pile of Superconductor Base HV Dust',
#  'Bronze Rotor',
#  'Tiny Pile of Polycaprolactam Pulp',
#  'Magnetic Steel Pickaxe Head',
#  '4x Superconductor HV Wire',
#  'Chromium Dioxide Screw',
#  'Dark Concrete Cobblestone',
#  'Flerovium Ingot',
#  'ME Smart Cable - Light Blue',
#  'Double Tungstensteel Plate',
#  'Ytterbium Frame Box',
#  'Small Wooden Fluid Pipe',
#  'TRISO ball (Uranium)',
#  'Pyrolusite Ore',
#  'Glauconite Ore',
#  'Jade Screw',
#  'Fine HSS-E Wire',
#  'White Metal Ingot',
#  'Double Mysterious Crystal Plate',
#  'Bull Pine Leaves',
#  'COMET - Compact Cyclotron',
#  'Polished Stone Brick',
#  'Vulcanite Sense Blade',
#  'Tungstencarbide Hammer Head',
#  'Vulcanite Drill Tip',
#  '1x Niobium-Titanium Wire',
#  'Prasiolite Dust',
#  'Titanium Ore',
#  'Double Lead Plate',
#  'Quad Cell Sodium Battery',
#  'Alduorite Ore',
#  'molten.trinium',
#  'Blood Infused Iron Shovel Head',
#  'Centrifuged Aluminium Ore',
#  'Vermiculite',
#  'Double High Durability Compound Steel Ingot',
#  'Mince Meat',
#  'Triple Knightmetal Plate',
#  'potion.speed',
#  'Mithril Screw',
#  'Molten Bedrockium Cell',
#  'Triple Meteoric Steel Plate',
#  'Long Jade Rod',
#  'Indium Ore',
#  'Purified Cryolite (F) Dust',
#  'Light Purified Tengam Arrow',
#  'Magnetic Samarium Hoe Head',
#  'Iridium Ingot',
#  'potion.potatojuice',
#  'Blood Infused Iron Casing',
#  'Hastelloy-W Bolt',
#  'Double Rubidium Ingot',
#  'Tiny Pile of Nichrome Dust',
#  'Magnesium Frame Box',
#  'Deep Iron Ring',
#  'Fusion Machine Casing',
#  'Tiny Pile of Migmatite Dust',
#  'HSS-G Ring',
#  'Diatomite Ore',
#  'Vinteum Axe Head',
#  'Pollucite Ore',
#  'Superconductor Base HV Round',
#  'Superconductor Base UEV Plate',
#  'Superconductor Base EV Spring',
#  'Small Pile of Cosmic Neutronium Dust',
#  'ME Smart Cable - Brown',
#  'Cosmic Neutronium Ingot',
#  'Molten Thorium Capsule',
#  'Bronze Turbine Blade',
#  'Impure Pile of Certus Quartz Dust',
#  'Soapstone Ore',
#  'Heat Proof Coke Oven Casing',
#  'Integral Encasement II',
#  'Awakened Draconium Hammer Head',
#  'Gold Sword Blade',
#  'Lightly Steam-Cracked Refinery Gas Cell',
#  'Blood Channel',
#  'Farm Valve',
#  'Basic Circuit Board',
#  'Polyethylene Sword Blade',
#  'Quadruple Polyethylene Bar',
#  'Magnetic Neodymium Pickaxe Head',
#  'Sodium Fluoride Cell',
#  'Purified Crushed Lanthanite (Ce) Ore',
#  'Triple Ichorium Ingot',
#  'Block of Nickel Aluminide',
#  'Steeleaf Sword Blade',
#  'Alduorite Bolt',
#  'Small Wood Gear',
#  'Obscurator',
#  'Cerium Plate',
#  'Scrap',
#  'Elven Elementium Round',
#  'Chipped Fayalite',
#  'White Dwarf Matter Turbine Blade',
#  'Germanium Plasma Cell',
#  'Enriched Holmium Foil',
#  'Tiny Pile of Mince Meat',
#  'Solar Salt (Hot) Cell',
#  'Thermal Padding Helm',
#  'Quintuple Europium Ingot',
#  'ME Smart Cable - Black',
#  'Firestone Ore',
#  'Certus Quartz Hoe',
#  'Lead Sword Blade',
#  'molten.ademic steel',
#  'Massicot Dust',
#  'Steel Chainsaw Tip',
#  'Paper Ring',
#  'Quadruple Palladium Plate',
#  'Polydimethylsiloxane Pulp',
#  'Light Black Bronze Arrow',
#  'Adamantium Buzzsaw Blade',
#  'Black Plutonium Shovel Head',
#  'Small Pile of Superconductor Base UV Dust',
#  'Triple Steeleaf Plate',
#  'Purified Pile of Brown Limonite Dust',
#  'End Steel Drill Tip',
#  'Moderately Steam-Cracked Heavy Fuel Cell',
#  'plasma.nickel',
#  'Tiny Pile of Fluorite (F) Dust',
#  'Greenheart Wood Planks',
#  'Vanadiumsteel Hammer Head',
#  'Exquisite Dragonstone',
#  'Farm Control',
#  'Celestial Tungsten Bolt',
#  'Garnierite Ore',
#  'Melodic Alloy Round',
#  'Block of High Durability Compound Steel',
#  'Dreamwood Ring',
#  'Cyan Stained Pane',
#  'molten.vanadium',
#  'Mahoe Stairs',
#  'Muon',
#  'Basic Electrolyzer',
#  'Clay Compound Bolt',
#  'Tiny Pile of Uranium 233 Dust',
#  'Thulium Ingot',
#  'Pumice Ore',
#  'Small Prasiolite Ore',
#  'Sunnarium Gear',
#  'HeLiCoPtEr Plate',
#  'Tiny Pile of Wollastonite Dust',
#  'Leather Cap',
#  'Netherrack',
#  '2x Red Alloy Wire',
#  'Small Pile of HG-1223 Dust',
#  'Naquadria Arrow',
#  'Shadow Iron Screw',
#  'Small Manyullyn Spring',
#  'Shadow Steel Chainsaw Tip',
#  'HSS-E Gear',
#  'Tiny Pile of Spodumene Dust',
#  'Duralumin Spring',
#  'Infinity Catalyst Screw',
#  'HSS-E Hammer Head',
#  'Quadruple Blood Infused Iron Plate',
#  'Erbium Rotor',
#  'Obsidian Screw',
#  'Vanadium Screw',
#  'Pulsating Iron Drill Tip',
#  'Glass Rod',
#  'Centrifuged Niobium Ore',
#  'Brass Spring',
#  'Quadruple Battery Alloy Ingot',
#  'Fluid Pattern Encoder',
#  'Larch Wood Planks (Fireproof)',
#  'ME Dense Covered Cable - Orange',
#  'Severely Hydro-Cracked Propane Cell',
#  'Wooden Turning Blank',
#  'Nightvision Goggles',
#  'Deep Iron Turbine Blade',
#  'Advanced Muffler Hatch (UV)',
#  'Tiny Pile of Zirconium Dust',
#  'Tiny Pile of Osmium Dust',
#  'Nether Quartz Hoe Head',
#  'BISO pebble compound',
#  'Polyurethane Resin Cell',
#  'Ordo Arrow Head',
#  'Small Pile of Incoloy-020 Dust',
#  'Molten Chrome Cell',
#  'Small Pile of Superconductor Base EV Dust',
#  'Purified Tengam Screw',
#  'Limpid Water Catalyst',
#  'Poplar Wood Planks',
#  'Nonuple PBI Fluid Pipe',
#  'Quadruple Cerium Plate',
#  'Heavy Duty Alloy Ingot T1',
#  'Invar Ingot',
#  'Extruder Shape (Ingot)',
#  'Magnetic Neodymium File Head',
#  'Naquadah Rod',
#  'Niobium Carbide Screw',
#  'Alveary Fan',
#  'Dense Magnalium Plate',
#  'Nickel Ring',
#  'Fine Cupronickel Wire',
#  'Quadruple Barium Ingot',
#  'Naquadah Alloy Gear',
#  'Tungstencarbide Rotor',
#  'White Dwarf Matter Arrow',
#  'Alveary',
#  'Double Copper Plate',
#  'Block of Uranium 238',
#  'Small Pile of Lanthanum Dust',
#  'Sapphire Lens',
#  'Vivid Alloy Axe Head',
#  'molten.lithiumfluoride',
#  'dye.chemical.dyelime',
#  'Long Lutetium Rod',
#  'Attuned Tengam Nugget',
#  'Raw Veggie Pizza',
#  'Small Annealed Copper Gear',
#  'Fine Stainless Steel Wire',
#  'Meteoric Iron Ore',
#  'Jade Hoe Head',
#  'Small Pile of Rubber Pulp',
#  'Tiny Pile of Sodium Sulfide Dust',
#  'Fine Ademic Steel Wire',
#  'Quantum Power IC',
#  'Bismuth Ore',
#  'Small Callisto Ice Spring',
#  'Stainless Steel Rotor',
#  'Block of Lead',
#  'molten.osmiridium',
#  'Quadruple Steeleaf',
#  'Sticky Glue Bucket',
#  'ME Covered Cable - Light Blue',
#  'Tiny Pile of Massicot Dust',
#  'Hazmat Suit',
#  'Quintuple Red Alloy Ingot',
#  'Mytryl Gear',
#  'Advanced Magneto Resonatic Circuit',
#  'Dense Strontium Plate',
#  'dye.chemical.dyeorange',
#  'Platinum Residue Dust',
#  'Styrene-Butadiene Rubber Sense Blade',
#  'Spodumene Ore',
#  'Iron Bars',
#  'Tungstensteel Turbine Casing',
#  'Shadow Iron Foil',
#  'Primitive Magneto Resonatic Circuit',
#  'Triple Fluxed Electrum Plate',
#  'Padauk Fence (Fireproof)',
#  'Green Stained Glass',
#  'Bismutite Turbine Blade',
#  'Advanced Plasma Arc Furnace IV',
#  'Quadruple Elven Elementium Ingot',
#  'Matter Ball',
#  '2x Duranium Cable',
#  'Pyrolusite Ore',
#  'Hydrogen Sulfide Cell',
#  'Desh Axe',
#  'Quintuple Soularium Ingot',
#  'Quadruple Superconductor Base HV Plate',
#  'Mossy Basalt Bricks',
#  '1x Osmium Wire',
#  'Tritanium Ore',
#  'Crystalline Pink Slime Universal Spade Head',
#  'Red Alloy Rod',
#  'Plasma Membrane',
#  'Small Pile of Emerald Dust',
#  'Basic Dehydrator II',
#  'Chalcopyrite Ore',
#  'Soularium Spring',
#  'Perditio Hoe Head',
#  'Realgar Drill Tip',
#  'Citrus Wood',
#  'Small Coal Boiler',
#  'Silver Nugget',
#  'Lepersonnite Ore',
#  'Quadruple Vulcanite Plate',
#  'Exquisite Forsterite',
#  'Quartz Slab',
#  'Electric Motor (MV)',
#  'Long Trinium Rod',
#  'Molten Soularium Capsule',
#  'Small Pile of Migmatite Dust',
#  'Long Vibrant Alloy Rod',
#  'Tellurium Gear',
#  'Electron Cell',
#  'Advanced Redstone Receiver (Internal)',
#  'Purified Crushed Yttrocerite Ore',
#  'Jade Ore',
#  'lava',
#  'Quartz Sand',
#  'Triple Superconductor Base UMV Plate',
#  'Tiny Pile of Aer Crystal Powder',
#  'Diamond Sword',
#  '16x Silver Cable',
#  'molten.phosphorousuraniumhexafluoridepuf6',
#  'Small Pile of Copper(II) Sulfate Pentahydrate Dust',
#  'Epoxid Chainsaw Tip',
#  'Quantium Rotor',
#  'Hardened Casing',
#  'Bastnasite Ore',
#  'Volcanus',
#  'Naquadah Sword Blade',
#  'Red Garnet Dust',
#  'Larch Wood Planks',
#  'Ground Fullers Earth',
#  'molten.niobiumtitanium',
#  'fluid.coalgas',
#  'Quintuple Rubracium Plate',
#  'Raw Silicon Casing',
#  'Crushed Topaz Ore',
#  'Maraging Steel 300 Rotor',
#  'Mysterious Crystal Casing',
#  'Quadruple Cosmic Neutronium Plate',
#  'Zeron-100 Frame Box',
#  'Nickel Aluminide Ingot',
#  'Bismuth Tellurite Dust',
#  'Force Plasma Cell',
#  'Crushed Awakened Draconium Ore',
#  'Centrifuged Erbium Ore',
#  'Nichrome Shovel Head',
#  'Congealed Green Slime',
#  'molten.ironwood',
#  'Long Tungsten Rod',
#  'Calcium Carbonate Dust',
#  'Palladium Hammer Head',
#  'potion.diablosauce',
#  'Long Vyroxeres Rod',
#  'Callisto Ice Ingot',
#  'Purified Pile of Crude Rhodium Metal Dust',
#  'Cosmic Neutronium Universal Spade Head',
#  'Quadruple Purified Tengam Plate',
#  'Small Pile of Vulcanite Dust',
#  'Golden Carrot',
#  'Molten Callisto Ice Cell',
#  'molten.palladium',
#  'Tool Forge',
#  'Mytryl Chainsaw Tip',
#  'Ledox Hoe Head',
#  'Osmiridium Saw Blade',
#  'Large Infinity Fluid Pipe',
#  'Small Tungsten Gear',
#  'Thorium Hexafluoride Cell',
#  'Inconel-625 Frame Box',
#  'Force Ingot',
#  'Launch Controller',
#  'Bolted Gold Casing',
#  'Block of Fayalite',
#  'Naquadah Alloy Nugget',
#  'Manyullyn Ore',
#  'Purified Niter Ore',
#  'Battery Alloy Ingot',
#  '8x Superconductor Base UMV Wire',
#  'Universium Round',
#  'Purified Tengam Saw Blade',
#  'Triple Infused Gold Ingot',
#  'Zirconium Carbide Ingot',
#  'Heavy Fuel Cell',
#  'Iron Rotor Blade',
#  'Large Maraging Steel 300 Fluid Pipe',
#  'Zircon Dust',
#  'Double Ancient Granite Plate',
#  'Brass Gear',
#  'Kanthal Casing',
#  'Triple Vulcanite Ingot',
#  'Quartz Sand',
#  '8x Soldering Alloy Wire',
#  'Sterling Silver Nugget',
#  'MFE',
#  'Niobium Ore',
#  '4x TPV-Alloy Cable',
#  'Triple Barium Plate',
#  'Triple Terrasteel Plate',
#  'Tiny Pile of Molybdenite Dust',
#  'Duralumin Ore',
#  'Tiny Pile of Chocolate Powder',
#  'Diamond Pickaxe',
#  'Infinity Catalyst Ore',
#  'Duranium Rod',
#  'Triple Ytterbium Plate',
#  'Raw Carbon Mesh',
#  'Block of Octiron',
#  'Medium Acid Battery',
#  'Bismuth Bronze Turbine Blade',
#  'High Temperature Gas-cooled Reactor',
#  'Triple Superconductor Base IV Ingot',
#  'Iron Ore',
#  'Quartzite Casing',
#  'Muffler Hatch (IV)',
#  'Tiny Pile of Ruthenium Dust',
#  'Molten Gaia Spirit Cell',
#  'Molybdenum Sword Blade',
#  'Iron Plow Head',
#  'Quadruple Sterling Silver Ingot',
#  'Tungsten Ore',
#  'Molybdenum Hoe Head',
#  'Molten Borosilicate Glass Cell',
#  'Cinobite A243 Screw',
#  'White Dwarf Extruder Shape (Block)',
#  '12x Niobium-Titanium Cable',
#  'Tricalcium Phosphate Rod',
#  'Pyrolusite Ore',
#  'Dense Nickel Plate',
#  'Germanium Frame Box',
#  'Quintuple Infinity Plate',
#  'Advanced Circuit',
#  'Kanthal Universal Spade Head',
#  'Yellow Garnet Dust',
#  'Endium Ore',
#  'acidic osmium solution',
#  'Crushed Brown Limonite Ore',
#  'molten.meteoricsteel',
#  'Light Ledox Arrow',
#  'Wrought Iron Pickaxe Head',
#  'Quadruple Lutetium Ingot',
#  'Small Dysprosium Spring',
#  '§a16k§r ME Multi-Fluid Storage Cell',
#  'Tiny Pile of Soda Ash Dust',
#  'Kapok Fence (Fireproof)',
#  'Black Titanium Dust',
#  'Titanium Sword',
#  'Molten Praseodymium Cell',
#  '12x Black Steel Wire',
#  'Banded Iron Ore',
#  'Block of Nichrome',
#  'Quadruple Superconductor Base LuV Ingot',
#  'Potin Ingot',
#  'Quintuple Niobium Nitride Plate',
#  '4x Silver Cable',
#  'Niobium-Titanium Rod',
#  'Hastelloy-X Frame Box',
#  'Strontium Ingot',
#  'Dark Iron Shovel Head',
#  'Thorium Tetrafluoride Dust',
#  'Silicon Carbide Rotor',
#  'plasma.gallium',
#  'Tiny Pile of Refined Platinum Salt Dust',
#  'Talonite Rotor',
#  'Input Hatch (IV)',
#  'Uranium 238 Saw Blade',
#  'HeLiCoPtEr Dust',
#  'Bedrockium Ingot',
#  'Advanced Containment Unit',
#  'Manyullyn Dust',
#  'Palm Wood Planks',
#  '3,3-Diaminobenzidine Capsule',
#  'Asbestos Ore',
#  'Molten Endium Cell',
#  'ME Controller',
#  'Long Wood Stick',
#  'Terbium Ore',
#  'Gold Plate',
#  'Yttrium Bolt',
#  'Tin Alloy Dust',
#  'Draconium Chainsaw Tip',
#  'Block of Neutronium',
#  'Styrene-Butadiene Rubber Rod',
#  'Impure Pile of Strontium Dust',
#  'Water Cell',
#  '12x Lead Wire',
#  'Ceruclase Hoe Head',
#  'Polytetrafluoroethylene Pickaxe Head',
#  'Block of Aluminium',
#  'Black Stained Glass Pane',
#  'Quad Core Co-Processing Unit',
#  'Gelid Cryotheum Cell',
#  'Quadruple Superconductor Base IV Plate',
#  'High Voltage Regulator',
#  'Soldering Alloy Dust',
#  'Realgar Rod',
#  'Triple Cosmic Neutronium Ingot',
#  'Dimensionally Transcendent Residue Cell',
#  'ME Covered Cable - Yellow',
#  'Ironwood Wrench Tip',
#  'Tiny Pile of Cocoa Powder',
#  'Impure Pile of Leach Residue Dust',
#  'TPV-Alloy File Head',
#  'molten.manganese',
#  'Oak Wood Planks',
#  'Small Cupronickel Spring',
#  'Ichorium Buzzsaw Blade',
#  'Blood Steel Dust',
#  'Stibnite Ore',
#  'SMD Transistor',
#  'Nickel Screw',
#  'Perditio Bolt',
#  'Exquisite Red Zircon',
#  'Tin Alloy Universal Spade Head',
#  'Nitrogen Dioxide Cell',
#  'Molten Crystalline Pink Slime Cell',
#  'Block of Maraging Steel 350',
#  'Burned Out TRISO pebble ball',
#  'Tiny Pile of Phthalic Anhydride Dust',
#  'Lithium 7 Nugget',
#  'Advanced RE-Battery',
#  'molten.chrome',
#  'Battery',
#  'Red Steel Drill Tip',
#  'Vanadiumsteel Sense Blade',
#  'Blood Infused Iron Hammer Head',
#  '2x Annealed Copper Cable',
#  'Magenta Painter',
#  'Tiny Pile of Organorhodium Catalyst Dust',
#  '180k He Coolant Cell',
#  'Energetic Alloy Hoe Head',
#  'Magnetic Steel Casing',
#  'Lait au cafe',
#  'Barium Ore',
#  'Dense Tellurium Plate',
#  'Celestial Tungsten Foil',
#  'ME Glass Cable - Blue',
#  'Huge Transcendent Metal Fluid Pipe',
#  'Tiny Pile of Silicone Rubber Pulp',
#  'Cupronickel Frame Box',
#  'Dense Mithril Plate',
#  'Rubidium Plasma Cell',
#  '360k He Coolant Cell',
#  'Small Purified Tengam Spring',
#  'Fine Grisium Wire',
#  'Crushed Apatite Ore',
#  'Double Gaia Spirit Ingot',
#  'Tungstensteel Sense Blade',
#  'Clay',
#  'Fine Rose Gold Wire',
#  'Chiseled Brownstone',
#  'Arsenopyrite Ore',
#  'SpaceTime Ingot',
#  'Infused Gold Wrench Tip',
#  'Small Pile of Energy Crystal Dust',
#  'Wooden Slab',
#  'Tartarite Plate',
#  'Tiny Pile of Stibnite Dust',
#  'Advanced Electrolyzer III',
#  'Galena Dust',
#  'Tiny Pile of Hastelloy-X Dust',
#  'Fine Ardite Wire',
#  'Ultra Low Voltage Coil',
#  'Universium Plow Head',
#  'Rubber Round',
#  'Crushed Chromite Ore',
#  'Copper Screw',
#  'Uraninite Ore',
#  'Small Mytryl Spring',
#  'Mytryl Ore',
#  'Vivid Alloy Foil',
#  'Triple Alumite Ingot',
#  'Purified Crushed Rare Earth (I) Ore',
#  'Yttrocerite Ore',
#  'Steel Rod',
#  'Wenge Plank',
#  'Ceruclase Plow Head',
#  'Purified Aluminium Fluoride Ore',
#  'Small Epoxid Spring',
#  'Transmission Component (IV)',
#  'Cobalt Rotor',
#  'Palladium Hoe Head',
#  'Radiation Proof Machine Casing',
#  'Small Pile of Bismuth Dust',
#  'Ordo Infused Stone',
#  'Pyrochlore Ore',
#  'Molybdenum Dust',
#  'Sterling Silver Sense Blade',
#  'Purified Thulium Ore',
#  'Irarsite Ore',
#  'Superconductor Base ZPM Foil',
#  'Hemp Seeds',
#  'Flawless Magneto Resonatic',
#  'Large Cadmium Battery',
#  'formic acid',
#  'Small Pile of Arsenic Trioxide Dust',
#  'Double Orichalcum Plate',
#  'Uranium 238 Ore',
#  'Mica Dust',
#  'Molten Uranium 238 Cell',
#  'Double Niobium Plate',
#  'Silicone Rubber Shovel Head',
#  '4x Nichrome Wire',
#  'Sealed Wood Foil',
#  'Fine Thaumium Wire',
#  'Black Plutonium Bolt',
#  'Nichrome Nugget',
#  'Black Bronze Foil',
#  'Quintuple Iridium Plate',
#  'Small Pile of HS188-A Dust',
#  'Rock Salt Ore',
#  'Polyethylene Sense Blade',
#  'High Durability Compound Steel Bolt',
#  'Thulium Round',
#  'Deep Iron Ore',
#  'molten.astralsilver',
#  'Centrifuged Powellite Ore',
#  'Block of Holmium',
#  'Tiny Pile of Palladium Metallic Powder Dust',
#  'Double Terbium Plate',
#  'Quintuple Steeleaf Plate',
#  'Quadruple Melodic Alloy Ingot',
#  'Orichalcum Gear',
#  'Double Vibrant Alloy Plate',
#  '16x Nickel Wire',
#  'Small Livingwood Gear',
#  'Tiny Pile of Antimony Trioxide Dust',
#  'Samarium Ore',
#  'Crocoite Ore',
#  'Amber Arrow',
#  '4x Tin Wire',
#  ...]
