# %%
import json
import pandas as pd

# %%
def parse_json(filename, class_type, encoding="utf-8"):
    with open(filename, "r", encoding=encoding) as f:
        return class_type(**json.load(f))

# %%
from tools.dump_format import RecipeStacks
from tools.nerd_format import RecipeFile, Recipe
from tools.st_format import STDataFile
from tools.config_format import Config
stacks = parse_json("data/recipes_stacks.json", RecipeStacks)
st_file = parse_json("data/st_ex_data.json", STDataFile)
recipe_file = parse_json("data/recipes_preprocessed.json", RecipeFile, encoding="cp1252")

# %%
config = parse_json("config.json", Config)
config
# Out:
# Config(filter=FilterConfig(handler_names=['crafting'], handler_mods=['GT: New Horizons', 'GregTech', 'BartWorks', 'GTNH: Lanthanides', 'Railcraft', 'Good Generator', 'Ender IO'], exclude_handler_names=['gt.recipe.packager', 'gt.recipe.unpackager', 'gregtech.nei.multiblockhandler', 'gt.recipe.mixer', 'gt.recipe.centrifuge', 'gt.recipe.electrolyzer', 'gtpp.recipe.chemicaldehydrator', 'gt.recipe.chemicalreactor'], exclude_recipes=[RecipeFilter(machines=['Shaped Crafting', 'Shapeless Crafting'], inputs=IngredientExactFilter(kind='exactly_match', oredict=['dust.*'], num_matches=[1]), outputs=IngredientAnyFilter(kind='all_match_any', oredict=['dustTiny.*', 'dustSmall.*'])), RecipeFilter(machines=None, inputs=IngredientAnyFilter(kind='any_match_any', oredict=['tool.*', 'craftingTool.*']), outputs=None)]))

# %%
st_file.recipes.items()
# Out:
# dict_items([('Recipe_AILimiter_C', Recipe(slug='ai-limiter', name='AI Limiter', className='Recipe_AILimiter_C', alternate=False, time=12, manualTimeMultiplier=1.0, ingredients=[RecipeItem(item='Desc_CopperSheet_C', amount=5.0), RecipeItem(item='Desc_HighSpeedWire_C', amount=20.0)], forBuilding=False, inMachine=True, inHand=True, inWorkshop=False, products=[RecipeItem(item='Desc_CircuitBoardHighSpeed_C', amount=1.0)], producedIn=['Desc_AssemblerMk1_C'], isVariablePower=False, minPower=None, maxPower=None)), ('Recipe_Alternate_AdheredIronPlate_C', Recipe(slug='alternate-adhered-iron-plate', name='Alternate: Adhered Iron Plate', className='Recipe_Alternate_AdheredIronPlate_C', alternate=True, time=16, manualTimeMultiplier=1.0, ingredients=[RecipeItem(item='Desc_IronPlate_C', amount=3.0), RecipeItem(item='Desc_Rubber_C', amount=1.0)], forBuilding=False, inMachine=True, inHand=False, inWorkshop=False, products=[RecipeItem(item='Desc_IronPlateReinforced_C', amount=1.0)], producedIn=['Desc_AssemblerMk1_C'], isVariablePower=False, minPower=None, maxPower=None)), ('Recipe_Alternate_AlcladCasing_C', Recipe(slug='alternate-alclad-casing', name='Alternate: Alclad Casing', className='Recipe_Alternate_AlcladCasing_C', alternate=True, time=8, manualTimeMultiplier=1.0, ingredients=[RecipeItem(item='Desc_AluminumIngot_C', amount=20.0), RecipeItem(item='Desc_CopperIngot_C', amount=10.0)], forBuilding=False, inMachine=True, inHand=False, inWorkshop=False, products=[RecipeItem(item='Desc_AluminumCasing_C', amount=15.0)], producedIn=['Desc_AssemblerMk1_C'], isVariablePower=False, minPower=None, maxPower=None)), ('Recipe_Alternate_AutomatedMiner_C', Recipe(slug='alternate-automated-miner', name='Alternate: Automated Miner', className='Recipe_Alternate_AutomatedMiner_C', alternate=True, time=60, manualTimeMultiplier=1.0, ingredients=[RecipeItem(item='Desc_Motor_C', amount=1.0), RecipeItem(item='Desc_SteelPipe_C', amount=4.0), RecipeItem(item='Desc_IronRod_C', amount=4.0), RecipeItem(item='Desc_IronPlate_C', amount=2.0)], forBuilding=False, inMachine=True, inHand=False, inWorkshop=False, products=[RecipeItem(item='BP_ItemDescriptorPortableMiner_C', amount=1.0)], producedIn=['Desc_ManufacturerMk1_C'], isVariablePower=False, minPower=None, maxPower=None)), ('Recipe_Alternate_Beacon_1_C', Recipe(slug='alternate-crystal-beacon', name='Alternate: Crystal Beacon', className='Recipe_Alternate_Beacon_1_C', alternate=True, time=120, manualTimeMultiplier=1.0, ingredients=[RecipeItem(item='Desc_SteelPlate_C', amount=4.0), RecipeItem(item='Desc_SteelPipe_C', amount=16.0), RecipeItem(item='Desc_CrystalOscillator_C', amount=1.0)], forBuilding=False, inMachine=True, inHand=False, inWorkshop=False, products=[RecipeItem(item='BP_EquipmentDescriptorBeacon_C', amount=20.0)], producedIn=['Desc_ManufacturerMk1_C'], isVariablePower=False, minPower=None, maxPower=None)), ('Recipe_Alternate_BoltedFrame_C', Recipe(slug='alternate-bolted-frame', name='Alternate: Bolted Frame', className='Recipe_Alternate_BoltedFrame_C', alternate=True, time=24, manualTimeMultiplier=1.0, ingredients=[RecipeItem(item='Desc_IronPlateReinforced_C', amount=3.0), RecipeItem(item='Desc_IronScrew_C', amount=56.0)], forBuilding=False, inMachine=True, inHand=False, inWorkshop=False, products=[RecipeItem(item='Desc_ModularFrame_C', amount=2.0)], producedIn=['Desc_AssemblerMk1_C'], isVariablePower=False, minPower=None, maxPower=None)), ('Recipe_Alternate_Cable_1_C', Recipe(slug='alternate-insulated-cable', name='Alternate: Insulated Cable', className='Recipe_Alternate_Cable_1_C', alternate=True, time=12, manualTimeMultiplier=1.0, ingredients=[RecipeItem(item='Desc_Wire_C', amount=9.0), RecipeItem(item='Desc_Rubber_C', amount=6.0)], forBuilding=False, inMachine=True, inHand=False, inWorkshop=False, products=[RecipeItem(item='Desc_Cable_C', amount=20.0)], producedIn=['Desc_AssemblerMk1_C'], isVariablePower=False, minPower=None, maxPower=None)), ('Recipe_Alternate_Cable_2_C', Recipe(slug='alternate-quickwir ...

# %%
handlers = pd.read_csv("data/handlers.csv")
handlers.describe()
# Out:
#        Handler Recipe Name                       Handler Class  \
# count                  301                                 301
# unique                 268                                 171
# top       §9NASA Workbench  gregtech.nei.GT_NEI_DefaultHandler
# freq                    11                                 131
#
#        Overlay Identifier Mod DisplayName ItemStack
# count                 222             301       301
# unique                201              47       266
# top              crafting        GregTech   Unknown
# freq                   19             113        14

# %%
# Map slug->oredict
oredict = pd.read_csv("data/oredict.csv", index_col="ItemStack")


item_df = pd.DataFrame.from_records([(k, v.name) for k, v in stacks.items.items()], columns=["slug", "name"], index="slug")
# Some items have the damage included in ".damage" notation, which doesn't match with the oredict (and is also inconsistent)
# Let's remove it
halves = item_df["name"].str.rsplit(".", n=1, expand=True)
item_df["name"][halves[1].notna() & halves[1].str.isnumeric()] = halves[0]
# Add 1x for stack notation
item_df["stack"] = "1x" + item_df["name"]

# Wildcard items are ones where damage actually means damage, and not a different item
# Match them with the items with damage values removed
wildcard_oredict = oredict[oredict["Wildcard"] == True]
wildcard_oredict.index = wildcard_oredict.index.str.rsplit("@", n=1, expand=True).get_level_values(0)
item_df = item_df.merge(wildcard_oredict["Ore Name"], left_on="stack", right_index=True, how="left")

# For non-wildcard cases, we must add the damage to the stack using @ notation
item_df["stack"] = item_df["stack"] + "@" + item_df.index.str.split("d", n=1, expand=True).get_level_values(1)
item_df = item_df.merge(oredict["Ore Name"], left_on="stack", right_index=True, how="left", suffixes=("_wild", "_normal"))

combined_orenames = item_df["Ore Name_normal"].fillna(item_df["Ore Name_wild"])
item_df["Ore Name"] = combined_orenames
item_df.drop(columns=["Ore Name_normal", "Ore Name_wild"], inplace=True)

# %%
slug_to_oredict = item_df["Ore Name"]
slug_to_oredict
# Out:
# slug
# 6574d0               dustImpureFlorencite
# 472d4878            oreRedgraniteOilsands
# 472d4877           oreRedgraniteSoapstone
# 482d5                           blockOpal
# 4350d19101        plateTriplePlutonium241
#                          ...
# 5805d0        plateDoubleMaragingSteel250
# 6779d0           dustFormaldehydeCatalyst
# 6383d0                dustPureZirconolite
# 5925d0               plateDenseHastelloyW
# 4351d2299             toolHeadShovelStone
# Name: Ore Name, Length: 31290, dtype: object

# %%
# Precompute oredict matches for every item
exclude_recipe_filters = config.filter.exclude_recipes
all_filters = set()
for f in exclude_recipe_filters:
    if f.inputs: all_filters.update(f.inputs.oredict)
    if f.outputs: all_filters.update(f.outputs.oredict)
slug_matches = pd.DataFrame(index=item_df.index, columns=list(all_filters), dtype=bool)

for filter_regex in all_filters:
    slug_matches[filter_regex] = slug_to_oredict.str.fullmatch(filter_regex, case=True)

slug_matches.describe()
# slug_matches.loc[["6574d0", "472d4877"]]["dust.*"].sum()
# stacks.items["4350d934"]
# Out:
#        dustSmall.* tool.* craftingTool.* dustTiny.* dust.*
# count        21929  21929          21929      21929  21929
# unique           2      2              2          2      2
# top          False  False          False      False  False
# freq         21168  18747          21868      21168  19237

# %%
import itertools
missing_slugs = set(slug_matches.index[slug_matches.isna().any(axis=1)]) - set(itertools.chain(*[[i.slug for i in r.inputs + r.outputs] for r in recipe_file.recipes]))
print(len(missing_slugs)) # WHY SO MANY??
print(next(iter(missing_slugs))) # 7002d0
print(stacks.items[next(iter(missing_slugs))]) # Entry still exists, but it's not in the oredict. I did a left join!!
print(all([i in stacks.items for i in missing_slugs])) #WHY!!!??
# Out:
# 2979
# 4352d32042
# id=4352 regName='gregtech:gt.metaitem.03' name='gt.metaitem.03.32042' displayName='NOR Memory Chip (Wafer)' nbt={'id': '4352S', 'Count': '1B', 'Damage': '32042S'}
# True

# %%
# RECIPE FILTERING
from collections import Counter
import itertools

import re
from tools.config_format import IngredientListFilter, RecipeFilter
from tools.nerd_format import Stack


filter_machines = set(
    handlers[
        (
            (
                handlers["Overlay Identifier"].apply(
                    lambda x: x in config.filter.handler_names
                )
            )
            | (
                handlers["Mod DisplayName"].apply(
                    lambda x: x in config.filter.handler_mods
                )
            )
        )
        & ~(
            handlers["Overlay Identifier"].apply(
                lambda x: x in config.filter.exclude_handler_names
            )
        )
    ]["Handler Recipe Name"]
)

missing_slugs_counter = 0

def matches_ingredient_list_filter(ingredients: list[Stack], filter: IngredientListFilter):
    slugs = [i.slug for i in ingredients]
    try:
        matches = slug_matches.loc[slugs]
        if filter.kind == "all_match_any":
            return matches[filter.oredict].any(axis=1).all()
        elif filter.kind == "any_match_any":
            return matches[filter.oredict].any().any()
        elif filter.kind == "exactly_match":
            return (matches[filter.oredict].sum(axis=0) == filter.num_matches).all()
        else: 
            raise ValueError("Invalid filter kind")
    except KeyError:
        global missing_slugs_counter
        missing_slugs_counter += 1
        return False

def matches_recipe_filter(recipe: Recipe, filter: RecipeFilter):
    if filter.machines and recipe.machine not in filter.machines: return False
    if filter.inputs and not matches_ingredient_list_filter(recipe.inputs, filter.inputs): return False
    if filter.outputs and not matches_ingredient_list_filter(recipe.outputs, filter.outputs): return False
    return True


def passes_filter(recipe: Recipe):
    return (recipe.machine in filter_machines) and not any(matches_recipe_filter(recipe, filter) for filter in exclude_recipe_filters)

# %%
original_len = len(recipe_file.recipes)

# filtered_len = len(list())
filtered = list(filter(passes_filter, recipe_file.recipes))

print("Original length:", original_len, "Filtered length:", len(filtered))
c = Counter(map(lambda x: x.machine, filtered))
print("Missing slugs:", missing_slugs_counter) # Few enough, I guess
print(c)
# Out:
# Original length: 159402 Filtered length: 85916
# Missing slugs: 30817
# Counter({'Arc Furnace Recycling': 9436, 'Macerator Recycling': 9357, 'Fluid Extractor Recycling': 8302, 'Bending Machine': 5720, 'Cutting Machine': 5073, 'Assembler': 4947, 'Shaped Crafting': 4527, 'Macerator': 3997, 'Fluid Solidifier': 3906, 'Alloy Smelter Recycling': 3707, 'Fluid Canner': 2898, 'Extruder': 2838, 'Chemical Bath': 2394, 'Forge Hammer': 1793, 'Shapeless Crafting': 1408, 'Alloy Smelter Molding': 1171, 'Lathe': 1104, 'Fluid Extractor': 1089, 'Multiblock Centrifuge': 1027, 'Wiremill': 1024, 'Laser Engraver': 966, 'Implosion Compressor': 772, 'Thermal Centrifuge': 688, 'Large Chemical Reactor': 658, 'Ore Washer': 654, 'Simple Dust Washer': 592, 'Alloy Smelter': 498, 'Compressor': 411, 'Distillery': 367, 'Blast Furnace': 339, 'Multiblock Mixer': 301, 'Multiblock Electrolyzer': 277, 'Primitive Blast Furnace': 266, 'Vacuum Freezer': 237, 'Autoclave': 204, 'Cryogenic Freezer': 193, 'Forming Press': 187, 'Electromagnetic Polarizer': 187, 'Shaped IC2 Crafting': 179, 'Scanner': 173, 'Brewery': 120, 'Distillation Tower': 112, 'Canner': 106, 'ABS Non-Alloy Recipes': 99, 'Replicator': 90, 'Chemical Plant': 89, 'Fermenter': 85, 'PCB Factory': 84, 'Assemblyline Process': 78, 'Forge Hammer Recycling': 76, 'Sifter': 71, 'Oil Cracker': 68, 'Multiblock Dehydrator': 67, 'Coke Oven': 66, 'Alloy Blast Smelter': 64, 'Extractor': 56, 'Bacterial Vat': 56, 'Pyrolyse Oven': 55, 'Fusion Reactor': 51, 'Tree Growth Simulator': 45, 'Shapeless IC2 Crafting': 44, 'Milling': 44, 'Plasma Generator Fuels': 44, 'Electromagnetic Separator': 40, 'Bio Lab': 34, 'Circuit Assembler': 32, 'Slicer': 28, 'Molecular Transformer': 24, 'COMET - Compact Cyclotron': 21, 'Zhuhai - Fishing Port': 21, 'Nuclear Fission': 21, 'Fireworks': 19, 'Circuit Assembly Line': 14, 'Fluid Heater': 14, 'Acid Generator': 12, 'Flotation Cell': 11, 'Vacuum Furnace': 11, 'Plasma Arc Furnace': 10, 'Nano Forge': 10, 'Transcendent Plasma Mixer': 6, 'Matter Fabricator': 6, 'Reactor Processing Unit': 6, 'Nuclear Fuel Processing': 5, 'Arc Furnace': 5, 'Large Boiler': 3, 'Thermal Generator Fuel': 3, 'Rock Breaker': 3, 'Printer': 3, 'Mass Fabrication': 2, 'Matter Amplifier': 2, 'DTPF': 2, 'Cold Trap': 2, 'Semifluid Boiler Fuels': 2, 'Naquadah Reactor MkII': 1, 'Naquadah Reactor MkIV': 1, 'Thermal Generator Fuels': 1, 'Solar Tower': 1, 'Naquadah Reactor MkI': 1, 'Naquadah Reactor MkIII': 1, 'Naquadah Reactor MkV': 1})

# %%
# Out:
# 4527

# %%
# Too friggin complicated, just use the slow loop method

# # Convert the recipe_file.recipes list into a DataFrame
# recipe_slugs_df = pd.DataFrame.from_records({"machine": r.machine, "inputs": [i.slug for i in r.inputs], "outputs": [o.slug for o in r.outputs]} for r in recipe_file.recipes)

# recipe_outputs_df = recipe_slugs_df[["outputs"]].explode('outputs')
# recipe_inputs_df = recipe_slugs_df[["inputs"]].explode('inputs')

# # Create a DataFrame for the filter machines
# filter_machines_df = pd.DataFrame({'machine': list(filter_machines)})

# # Merge the recipes_df with the filter_machines_df to add a column indicating whether the recipe machine is in the filter machines
# recipe_slugs_df = pd.merge(recipe_slugs_df, filter_machines_df, on='machine', how='inner')

# filts = pd.DataFrame.from_records([f.__dict__ for f in exclude_recipe_filters])

# %%
def print_item(item):
    slug = item.slug
    name = None
    if "d" in slug:
        if slug not in stacks.items:
            name = f"{slug} [MISSING]"
        else:
            name = f"{stacks.items[slug].displayName} [{slug_to_oredict.loc[slug]}]"
    else:
        if slug not in stacks.fluids:
            name = f"{slug} [MISSING]"
        else: 
            name =  stacks.fluids[slug].localizedName if hasattr(stacks.fluids[slug],"localizedName") else stacks.fluids[slug].unlocalizedName
    return f"({item.amount:10f}x) {slug:<16}: {name}"

def print_nice(recipe: Recipe):
    inputs = "\n\t".join(map(lambda x: print_item(x), recipe.inputs))
    outputs = "\n\t".join(map(lambda x: print_item(x), recipe.outputs))
    print("Inputs:\n\t"+ inputs)
    print("Outputs:\n\t"+ outputs)
    print("Machine:", recipe.machine)

# %%
print_nice(next(filter(lambda x: x.machine=="Shaped Crafting", filtered)))
# Out:
# Inputs:
# 	(         6x) 4350d11337      : Shadow Steel Ingot [ingotShadowSteel]
# 	(         1x) 4350d23305      : Steel Rod [stickSteel]
# Outputs:
# 	(         2x) 4355d12         : Hammer [craftingToolHardHammer]
# Machine: Shaped Crafting

# %%
slug_to_oredict[["4350d2809", "4355d24"]]
# Out:
# slug
# 4350d2809               dustWood
# 4350d2809               pulpWood
# 4355d24       craftingToolMortar
# 4355d24      toolMortarandpestle
# Name: Ore Name, dtype: object

# %%
filtered = list(set(filtered) - set(handtools))
len(filtered)
# Out:
# 97320

# %%
for i in range(0, len(filtered), len(filtered)//50):
    print_nice(filtered[i])
    print("*"*80)
# Out:
# Inputs:
# 	(  1.000000x) 459d1343        : 8x Cupronickel Wire [nan]
# Outputs:
# 	(  8.000000x) 459d1340        : 1x Cupronickel Wire [nan]
# Machine: Shapeless Crafting
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 6824d0          : Teflon Plate [plateTeflon]
# Outputs:
# 	(144.000000x) 1056            : molten.teflon
# Machine: Fluid Extractor
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d23043      : Rubidium Rod [stickRubidium]
# 	( 42.000000x) 52              : oxygen
# Outputs:
# 	(  4.000000x) 4350d9043       : Rubidium Nugget [nuggetRubidium]
# Machine: Arc Furnace Recycling
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d11028      : Titanium Ingot [ingotTitanium]
# Outputs:
# 	(144.000000x) 294             : molten.titanium
# Machine: Fluid Extractor Recycling
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 459d1307        : 2x Iron Cable [nan]
# Outputs:
# 	(  1.000000x) 4350d2032       : Iron Dust [slug
# 4350d2032    dustAnyIron
# 4350d2032       dustIron
# Name: Ore Name, dtype: object]
# 	(  1.000000x) 4350d2880       : Rubber Pulp [slug
# 4350d2880    dustAnyRubber
# 4350d2880       dustRubber
# Name: Ore Name, dtype: object]
# Machine: Macerator Recycling
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d11385      : Enhanced Galgadorian Ingot [ingotEnhancedGalgadorian]
# Outputs:
# 	(  1.000000x) 4350d23385      : Enhanced Galgadorian Rod [stickEnhancedGalgadorian]
# 	(  2.000000x) 4350d1385       : Small Pile of Enhanced Galgadorian Dust [dustSmallEnhancedGalgadorian]
# Machine: Lathe
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d18982      : Double Cosmic Neutronium Plate [plateDoubleCosmicNeutronium]
# Outputs:
# 	(  2.000000x) 4350d2982       : Cosmic Neutronium Dust [dustCosmicNeutronium]
# Machine: Macerator Recycling
# ********************************************************************************
# Inputs:
# 	(  2.000000x) 176d0           : Certus Quartz Block [nan]
# Outputs:
# 	(  2.000000x) 177d0           : Certus Quartz Pillar [nan]
# 	(  2.000000x) 178d0           : Chiseled Certus Quartz Block [nan]
# Machine: Shaped Crafting
# ********************************************************************************
# Inputs:
# 	(  5.000000x) 4350d11340      : Meteoric Iron Ingot [ingotMeteoricIron]
# 	(  1.000000x) 4349d5          : Programmed Circuit [nan]
# Outputs:
# 	(  1.000000x) 4350d21340      : Quintuple Meteoric Iron Plate [plateQuintupleMeteoricIron]
# Machine: Bending Machine
# ********************************************************************************
# Inputs:
# 	(  4.000000x) 459d1725        : 16x Niobium-Titanium Wire [nan]
# 	(  5.000000x) 4350d2649       : Polyvinyl Chloride Pulp [dustPolyvinylChloride]
# 	( 20.000000x) 4350d29360      : Niobium-Titanium Foil [foilNiobiumTitanium]
# 	(720.000000x) 416             : molten.silicone
# Outputs:
# 	(  4.000000x) 459d1731        : 16x Niobium-Titanium Cable [nan]
# Machine: Assembler
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d25036      : Zinc Round [roundZinc]
# Outputs:
# 	(  1.000000x) 4350d36         : Tiny Pile of Zinc Dust [dustTinyZinc]
# Machine: Macerator Recycling
# ********************************************************************************
# Inputs:
# 	(  2.000000x) 4350d2840       : Tetrahedrite Dust [dustTetrahedrite]
# 	(  2.000000x) 4350d2535       : Coal Dust [dustCoal]
# Outputs:
# 	(  3.000000x) 4350d11035      : Copper Ingot [slug
# 4350d11035    ingotAnyCopper
# 4350d11035       ingotCopper
# Name: Ore Name, dtype: object]
# 	(  9.000000x) 4350d9058       : Antimony Nugget [nuggetAntimony]
# 	(  2.000000x) 4350d816        : Tiny Pile of Dark Ashes [dustTinyDarkAsh]
# Machine: Primitive Blast Furnace
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d11389      : Callisto Ice Ingot [ingotCallistoIce]
# 	(  1.000000x) 4350d32350      : Extruder Shape (Plate) [nan]
# Outputs:
# 	(  1.000000x) 4350d17389      : Callisto Ice Plate [plateCallistoIce]
# Machine: Extruder
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4351d6352       : Black Bronze File Head [toolHeadFileBlackBronze]
# 	(196.000000x) 52              : oxygen
# Outputs:
# 	(  2.000000x) 4350d11352      : Black Bronze Ingot [ingotBlackBronze]
# Machine: Arc Furnace Recycling
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d32302      : Mold (Casing) [nan]
# 	( 72.000000x) 380             : molten.tartarite
# Outputs:
# 	(  1.000000x) 4351d18956      : Tartarite Casing [itemCasingTartarite]
# Machine: Fluid Solidifier
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d3513       : Impure Pile of Blue Topaz Dust [dustImpureBlueTopaz]
# Outputs:
# 	(  1.000000x) 4350d2513       : Blue Topaz Dust [dustBlueTopaz]
# 	(  0.111100x) 4350d2507       : Topaz Dust [dustTopaz]
# Machine: Multiblock Centrifuge
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d21063      : Quintuple Barium Plate [plateQuintupleBarium]
# Outputs:
# 	(  5.000000x) 4350d2063       : Barium Dust [dustBarium]
# Machine: Macerator Recycling
# ********************************************************************************
# Inputs:
# 	(  4.000000x) 459d1764        : 12x Yttrium Barium Cuprate Wire [nan]
# 	(  4.000000x) 4350d2649       : Polyvinyl Chloride Pulp [dustPolyvinylChloride]
# 	( 16.000000x) 4350d29631      : Polyphenylene Sulfide Foil [foilPolyphenyleneSulfide]
# 	(576.000000x) 416             : molten.silicone
# Outputs:
# 	(  4.000000x) 459d1770        : 12x Yttrium Barium Cuprate Cable [nan]
# Machine: Assembler
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d9970       : Void Nugget [nuggetVoid]
# Outputs:
# 	(  1.000000x) 4350d25970      : Void Round [roundVoid]
# Machine: Lathe
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4354d369        : Molten Conductive Iron Cell [cellMoltenConductiveIron]
# Outputs:
# 	(  1.000000x) 4247d0          : Empty Cell [cellEmpty]
# 	(144.000000x) 628             : molten.conductiveiron
# Machine: Fluid Canner
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4351d16310      : Cupronickel Turbine Blade [turbineBladeCupronickel]
# Outputs:
# 	(864.000000x) 403             : molten.cupronickel
# Machine: Fluid Extractor Recycling
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4351d25529      : Vinteum Arrow [arrowGtWoodVinteum]
# 	( 18.000000x) 164             : molten.blaze
# Outputs:
# 	(  1.000000x) 4351d25529      : Vinteum Arrow [arrowGtWoodVinteum]
# Machine: Chemical Bath
# ********************************************************************************
# Inputs:
# 	(  5.000000x) 4350d11364      : Dark Steel Ingot [ingotDarkSteel]
# 	(  1.000000x) 4350d32374      : Extruder Shape (Rotor) [nan]
# Outputs:
# 	(  1.000000x) 4351d21364      : Dark Steel Rotor [rotorDarkSteel]
# Machine: Extruder
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d29314      : Soldering Alloy Foil [foilSolderingAlloy]
# Outputs:
# 	( 36.000000x) 554             : molten.solderingalloy
# Machine: Fluid Extractor Recycling
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 35d0            : Wool [nan]
# 	( 72.000000x) 139             : dye.chemical.dyeblue
# Outputs:
# 	(  1.000000x) 35d11           : Blue Wool [nan]
# Machine: Chemical Bath
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d14305      : Triple Steel Ingot [ingotTripleSteel]
# Outputs:
# 	(  3.000000x) 4350d2305       : Steel Dust [dustSteel]
# Machine: Macerator Recycling
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d6500       : Purified Diamond Ore [crushedPurifiedDiamond]
# Outputs:
# 	(  1.000000x) 4350d4500       : 4350d4500 [MISSING]
# 	(  0.100000x) 4350d2865       : Graphite Dust [dustGraphite]
# Machine: Macerator
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d30973      : Hexachlorodisilane Cell [cellHexachlorodisilane]
# Outputs:
# 	(  1.000000x) 4247d0          : Empty Cell [cellEmpty]
# 	(1000.000000x) 551             : 551 [MISSING]
# Machine: Fluid Canner
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d32322      : Mold (Ring) [nan]
# 	( 36.000000x) 351             : molten.fierysteel
# Outputs:
# 	(  1.000000x) 4350d28346      : Fiery Steel Ring [ringFierySteel]
# Machine: Fluid Solidifier
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 508d1           : Infinity Block [nan]
# Outputs:
# 	(1296.000000x) 649             : molten.infinity
# Machine: Fluid Extractor Recycling
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 721d5           : Wenge Wood Slab (Fireproof) [WengeSlab]
# 	(  4.000000x) 1               : tile.water
# Outputs:
# 	(  2.000000x) 4351d32481      : Wenge Plank [nan]
# Machine: Cutting Machine
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 459d1200        : 1x Cobalt Wire [nan]
# 	(  1.000000x) 4349d1          : Programmed Circuit [nan]
# Outputs:
# 	(  4.000000x) 4351d19033      : Fine Cobalt Wire [wireFineCobalt]
# Machine: Wiremill
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d5542       : Crushed Terra Crystals [crushedInfusedEarth]
# 	(200.000000x) 42              : fluidDistilledWater
# Outputs:
# 	(  1.000000x) 4350d6542       : Purified Terra Crystals [crushedPurifiedInfusedEarth]
# 	(  0.111100x) 4350d2542       : Terra Crystal Powder [dustInfusedEarth]
# 	(  1.000000x) 4350d2299       : Stone Dust [dustStone]
# Machine: Ore Washer
# ********************************************************************************
# Inputs:
# 	(  8.000000x) 4144d16         : ME Glass Cable - Fluix [nan]
# 	(  1.000000x) 4350d2887       : Cocoa Powder [slug
# 4350d2887          dustCocoa
# 4350d2887                dye
# 4350d2887           dyeBrown
# 4350d2887    foodCocoapowder
# Name: Ore Name, dtype: object]
# Outputs:
# 	(  8.000000x) 4144d12         : ME Glass Cable - Brown [nan]
# Machine: Shaped Crafting
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4351d18074      : Holmium Casing [itemCasingHolmium]
# 	(  1.000000x) 4350d32309      : Mold (Nuggets) [nan]
# Outputs:
# 	(  4.000000x) 4350d9074       : Holmium Nugget [nuggetHolmium]
# Machine: Alloy Smelter Recycling
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4351d19035      : Fine Copper Wire [slug
# 4351d19035    wireFineAnyCopper
# 4351d19035       wireFineCopper
# Name: Ore Name, dtype: object]
# 	( 16.000000x) 52              : oxygen
# Outputs:
# 	(  1.000000x) 4350d9345       : Annealed Copper Nugget [slug
# 4350d9345    nuggetAnnealedCopper
# 4350d9345         nuggetAnyCopper
# Name: Ore Name, dtype: object]
# Machine: Arc Furnace Recycling
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 336d0           : Brick [ingotBrick]
# Outputs:
# 	(  1.000000x) 4350d1625       : Small Pile of Brick Dust [dustSmallBrick]
# Machine: Macerator
# ********************************************************************************
# Inputs:
# 	(  9.000000x) 4350d11029      : Vanadium Ingot [ingotVanadium]
# Outputs:
# 	(  1.000000x) 480d0           : Block of Vanadium [blockVanadium]
# Machine: Compressor
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d11304      : Wrought Iron Ingot [slug
# 4350d11304        ingotAnyIron
# 4350d11304    ingotWroughtIron
# Name: Ore Name, dtype: object]
# 	(  1.000000x) 4350d32359      : Extruder Shape (Small Pipe) [nan]
# Outputs:
# 	(  1.000000x) 459d5261        : Small Wrought Iron Fluid Pipe [nan]
# Machine: Extruder
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d23986      : Superconductor Base UV Rod [stickLongasssuperconductornameforuvwire]
# 	(  1.000000x) 4349d1          : Programmed Circuit [nan]
# Outputs:
# 	(  2.000000x) 4351d23986      : Small Superconductor Base UV Spring [springSmallLongasssuperconductornameforuvwire]
# Machine: Bending Machine
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d18353      : Double Bismuth Bronze Plate [plateDoubleBismuthBronze]
# Outputs:
# 	(  2.000000x) 4350d2353       : Bismuth Bronze Dust [dustBismuthBronze]
# Machine: Macerator Recycling
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 459d2002        : 4x Red Alloy Wire [nan]
# 	(  2.000000x) 4350d17880      : Rubber Sheet [slug
# 4350d17880    plateAnyRubber
# 4350d17880       plateRubber
# 4350d17880       sheetRubber
# Name: Ore Name, dtype: object]
# Outputs:
# 	(  1.000000x) 459d2008        : 4x Red Alloy Cable [nan]
# Machine: Shapeless Crafting
# ********************************************************************************
# Inputs:
# 	(  9.000000x) 5156d0          : Rhenium Ingot [ingotRhenium]
# 	(  1.000000x) 4350d32363      : Extruder Shape (Block) [nan]
# Outputs:
# 	(  1.000000x) 719d0           : Block of Rhenium [blockRhenium]
# Machine: Extruder
# ********************************************************************************
# Inputs:
# 	(  2.000000x) 4350d18987      : Double Superconductor Base MV Plate [plateDoublePentacadmiummagnesiumhexaoxid]
# 	(  1.000000x) 4349d2          : Programmed Circuit [nan]
# Outputs:
# 	(  1.000000x) 4350d20987      : Quadruple Superconductor Base MV Plate [plateQuadruplePentacadmiummagnesiumhexaoxid]
# Machine: Bending Machine
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 459d1830        : 12x Duranium Cable [nan]
# 	(594.000000x) 52              : oxygen
# Outputs:
# 	(  6.000000x) 4350d11328      : Duranium Ingot [ingotDuranium]
# 	(  2.000000x) 4350d1815       : Small Pile of Ashes [dustSmallAsh]
# Machine: Arc Furnace Recycling
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d11316      : Tungstensteel Ingot [ingotTungstenSteel]
# Outputs:
# 	(  1.000000x) 4350d2316       : Tungstensteel Dust [dustTungstenSteel]
# Machine: Macerator Recycling
# ********************************************************************************
# Inputs:
# 	(  8.000000x) 4144d56         : ME Smart Cable - Fluix [nan]
# 	(  1.000000x) 351d6           : Cyan Dye [nan]
# Outputs:
# 	(  8.000000x) 4144d49         : ME Smart Cable - Cyan [nan]
# Machine: Shaped Crafting
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 7036d5          : Centrifuged Fluor-Buergerite Ore [crushedCentrifugedFluor-Buergerite]
# Outputs:
# 	(  1.000000x) 7020d5          : Fluor-Buergerite Dust [dustFluor-Buergerite]
# 	(  0.100000x) 4350d2837       : Silicon Dioxide Dust [dustSiliconDioxide]
# Machine: Macerator
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 459d1746        : 1x Vanadium-Gallium Cable [nan]
# Outputs:
# 	(  1.000000x) 4350d2880       : Rubber Pulp [slug
# 4350d2880    dustAnyRubber
# 4350d2880       dustRubber
# Name: Ore Name, dtype: object]
# 	(  2.000000x) 4350d1357       : Small Pile of Vanadium-Gallium Dust [dustSmallVanadiumGallium]
# Machine: Macerator Recycling
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d17077      : Ytterbium Plate [plateYtterbium]
# 	(  2.000000x) 109             : lubricant
# Outputs:
# 	(  2.000000x) 4351d18077      : Ytterbium Casing [itemCasingYtterbium]
# Machine: Cutting Machine
# ********************************************************************************
# Inputs:
# 	(  1.000000x) 4350d25066      : Praseodymium Round [roundPraseodymium]
# 	( 16.000000x) 52              : oxygen
# Outputs:
# 	(  1.000000x) 4350d9066       : Praseodymium Nugget [nuggetPraseodymium]
# Machine: Arc Furnace Recycling
# ********************************************************************************

# %%
filtered_file = RecipeFile(recipes=filtered, dump_version=recipe_file.dump_version, dump_sha=recipe_file.dump_sha)

with open("data/recipes_filtered.json", "w", encoding="utf-8") as f:
    f.write(filtered_file.model_dump_json())
